# %%
# Source - https://stackoverflow.com/a/69297835
# Posted by jmPicaza
# Retrieved 2026-01-17, License - CC BY-SA 4.0

from IPython.core.display import HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder.appName('iceberg-incremenatal')
    
    # Iceberg package (same as --packages)
    .config(
        "spark.jars.packages", "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.9.2"
    )
    
    # Catalog configuration
    .config("spark.sql.catalog.local", "org.apache.iceberg.spark.SparkCatalog")
    .config("spark.sql.catalog.local.type", "hadoop")
    .config("spark.sql.catalog.local.warehouse", "/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse")
        
    .getOrCreate()
    )

spark
# Out:
# 26/01/18 12:27:11 WARN Utils: Your hostname, codebase.local resolves to a loopback address: 127.0.0.1; using 192.168.1.7 instead (on interface en0)
# 26/01/18 12:27:11 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Ivy Default Cache set to: /Users/codebase/.ivy2/cache
# The jars for the packages stored in: /Users/codebase/.ivy2/jars
# org.apache.iceberg#iceberg-spark-runtime-3.5_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-90e4725e-4f79-4d26-af22-6817da4ab88a;1.0
# 	confs: [default]
# 	found org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.9.2 in central
# :: resolution report :: resolve 36ms :: artifacts dl 1ms
# 	:: modules in use:
# 	org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.9.2 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   1   |   0   |   0   |   0   ||   1   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-90e4725e-4f79-4d26-af22-6817da4ab88a
# 	confs: [default]
# 	0 artifacts copied, 1 already retrieved (0kB/2ms)
# 26/01/18 12:27:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.7:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.8</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>iceberg-incremenatal</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.sql("""
CREATE TABLE local.db.events (
  id BIGINT,
  name STRING,
  age BIGINT,
  ts TIMESTAMP
)
USING iceberg
TBLPROPERTIES (
  'write.parquet.stats-enabled.column.age' = 'true',
  'write.parquet.stats-enabled.column.event_time' = 'true'
)
""")
# Out:
# DataFrame[]

# %%
data_to_write = []
data = (1, "Charlie", 28, dt.now())
for i in range(1000_000):
    data_to_write.append(data)

# %%
from datetime import datetime as dt



# data = [(1, "Charlie", 28, dt.now()),
#         (3, "Diana", 34, dt.now())]

df = spark.createDataFrame(data_to_write, ["id", "name", "age", "ts"])

# %%
df.writeTo("local.db.events").append()
# Out:
# 26/01/18 12:34:43 WARN TaskSetManager: Stage 27 contains a task of very large size (1758 KiB). The maximum recommended task size is 1000 KiB.

# %%
spark.sql(
    """
    SELECT upper_bounds FROM local.db.events.files
    """
).show(truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------+
# |upper_bounds                                                                                                                 |
# +-----------------------------------------------------------------------------------------------------------------------------+
# |{1 -> [03 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [92 53 89 15 A4 48 06 00]}|
# |{1 -> [04 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [94 53 89 15 A4 48 06 00]}      |
# +-----------------------------------------------------------------------------------------------------------------------------+

# %%
spark.sql(
    """
    DESCRIBE TABLE EXTENDED local.db.events;
    """
).show(truncate=False)
# Out:
# +----------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |col_name                    |data_type                                                                                                                                                                                                            |comment|
# +----------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |id                          |bigint                                                                                                                                                                                                               |NULL   |
# |name                        |string                                                                                                                                                                                                               |NULL   |
# |age                         |bigint                                                                                                                                                                                                               |NULL   |
# |ts                          |timestamp                                                                                                                                                                                                            |NULL   |
# |                            |                                                                                                                                                                                                                     |       |
# |# Metadata Columns          |                                                                                                                                                                                                                     |       |
# |_spec_id                    |int                                                                                                                                                                                                                  |       |
# |_partition                  |struct<>                                                                                                                                                                                                             |       |
# |_file                       |string                                                                                                                                                                                                               |       |
# |_pos                        |bigint                                                                                                                                                                                                               |       |
# |_deleted                    |boolean                                                                                                                                                                                                              |       |
# |                            |                                                                                                                                                                                                                     |       |
# |# Detailed Table Information|                                                                                                                                                                                                                     |       |
# |Name                        |local.db.events                                                                                                                                                                                                      |       |
# |Type                        |MANAGED                                                                                                                                                                                                              |       |
# |Location                    |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events                                                                                                                                    |       |
# |Provider                    |iceberg                                                                                                                                                                                                              |       |
# |Owner                       |eren                                                                                                                                                                                                                 |       |
# |Table Properties            |[current-snapshot-id=4840837583587620844,format=iceberg/parquet,format-version=2,write.parquet.compression-codec=zstd,write.parquet.stats-enabled.column.age=true,write.parquet.stats-enabled.column.event_time=true]|       |
# +----------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+

# %%
from pyspark.sql.functions import col, max as spark_max

def iceberg_max_from_stats(table, ts_cols):
    """
    table   : 'local.db.events'
    ts_cols : ['ts', 'ingest_ts']
    """

    df = spark.table(f"{table}.files")

    return df.select([
        spark_max(
            col("readable_metrics")
            .getItem(c)
            .getField("upper_bound")
        ).alias(f"max_{c}")
        for c in ts_cols
    ])

# %%
iceberg_max_from_stats(
    "local.db.events",
    ["ts", "id"]
).show(truncate=False)
# Out:
# +--------------------------+------+
# |max_ts                    |max_id|
# +--------------------------+------+
# |2026-01-18 12:27:13.421716|4     |
# +--------------------------+------+

# %%
spark.sql(
    """
    SELECT * FROM local.db.events
    """
).show(truncate=False)
# Out:
# +---+-------+---+--------------------------+
# |id |name   |age|ts                        |
# +---+-------+---+--------------------------+
# |3  |Charlie|28 |2026-01-18 12:27:13.421714|
# |4  |Diana  |34 |2026-01-18 12:27:13.421716|
# +---+-------+---+--------------------------+

# %%
 df = spark.table(f"local.db.events.files")

# %%
df.show(50, truncate=False)
# Out:
# +-------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-----------+-------+------------+------------------+----------------------------------------+----------------------------------------------------+--------------------------------+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------+------------+-------------+------------+-------------+------------+--------------------+--------------+---------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |content|file_path                                                                                                                                            |file_format|spec_id|record_count|file_size_in_bytes|column_sizes                            |value_counts                                        |null_value_counts               |nan_value_counts|lower_bounds                                                                                                                 |upper_bounds                                                                                                                 |key_metadata|split_offsets|equality_ids|sort_order_id|first_row_id|referenced_data_file|content_offset|content_size_in_bytes|readable_metrics                                                                                                                                                                        |
# +-------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-----------+-------+------------+------------------+----------------------------------------+----------------------------------------------------+--------------------------------+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------+------------+-------------+------------+-------------+------------+--------------------+--------------+---------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/
|{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [01 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [33 AB A3 23 A4 48 06 00]}|{1 -> [01 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [33 AB A3 23 A4 48 06 00]}|NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 28, 28}, {49, 1, 0, NULL, 1, 1}, {52, 1, 0, NULL, Charlie, Charlie}, {49, 1, 0, NULL, 2026-01-18 12:31:10.029107, 2026-01-18 12:31:10.029107}}                        |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00009-79-99b94d55-d1ab-4633-b175-8f817079c517-0-00001.parquet |PARQUET    |0      |1           |1263              |{1 -> 49, 2 -> 50, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [03 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [3B AB A3 23 A4 48 06 00]}      |{1 -> [03 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [3B AB A3 23 A4 48 06 00]}      |NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 34, 34}, {49, 1, 0, NULL, 3, 3}, {50, 1, 0, NULL, Diana, Diana}, {49, 1, 0, NULL, 2026-01-18 12:31:10.029115, 2026-01-18 12:31:10.029115}}                            |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00004-64-45fa4130-c4e4-4f0e-b464-c548fc83bde6-0-00001.parquet |PARQUET    |0      |1           |1277              |{1 -> 49, 2 -> 52, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [01 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [76 F7 8E 23 A4 48 06 00]}|{1 -> [01 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [76 F7 8E 23 A4 48 06 00]}|NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 28, 28}, {49, 1, 0, NULL, 1, 1}, {52, 1, 0, NULL, Charlie, Charlie}, {49, 1, 0, NULL, 2026-01-18 12:31:08.672374, 2026-01-18 12:31:08.672374}}                        |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00009-69-45fa4130-c4e4-4f0e-b464-c548fc83bde6-0-00001.parquet |PARQUET    |0      |1           |1263              |{1 -> 49, 2 -> 50, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [03 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [7E F7 8E 23 A4 48 06 00]}      |{1 -> [03 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [7E F7 8E 23 A4 48 06 00]}      |NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 34, 34}, {49, 1, 0, NULL, 3, 3}, {50, 1, 0, NULL, Diana, Diana}, {49, 1, 0, NULL, 2026-01-18 12:31:08.672382, 2026-01-18 12:31:08.672382}}                            |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00004-54-d8d62ca0-9c7f-4263-9f07-2c0efb9c1106-0-00001.parquet |PARQUET    |0      |1           |1277              |{1 -> 49, 2 -> 52, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [01 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [CB AE 79 23 A4 48 06 00]}|{1 -> [01 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [CB AE 79 23 A4 48 06 00]}|NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 28, 28}, {49, 1, 0, NULL, 1, 1}, {52, 1, 0, NULL, Charlie, Charlie}, {49, 1, 0, NULL, 2026-01-18 12:31:07.277515, 2026-01-18 12:31:07.277515}}                        |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00009-59-d8d62ca0-9c7f-4263-9f07-2c0efb9c1106-0-00001.parquet |PARQUET    |0      |1           |1263              |{1 -> 49, 2 -> 50, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [03 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [D2 AE 79 23 A4 48 06 00]}      |{1 -> [03 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [D2 AE 79 23 A4 48 06 00]}      |NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 34, 34}, {49, 1, 0, NULL, 3, 3}, {50, 1, 0, NULL, Diana, Diana}, {49, 1, 0, NULL, 2026-01-18 12:31:07.277522, 2026-01-18 12:31:07.277522}}                            |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00004-44-b0d8404e-ac6b-4066-8924-45b1d1a25aa8-0-00001.parquet |PARQUET    |0      |1           |1277              |{1 -> 49, 2 -> 52, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [01 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [1A F0 60 23 A4 48 06 00]}|{1 -> [01 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [1A F0 60 23 A4 48 06 00]}|NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 28, 28}, {49, 1, 0, NULL, 1, 1}, {52, 1, 0, NULL, Charlie, Charlie}, {49, 1, 0, NULL, 2026-01-18 12:31:05.655834, 2026-01-18 12:31:05.655834}}                        |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00009-49-b0d8404e-ac6b-4066-8924-45b1d1a25aa8-0-00001.parquet |PARQUET    |0      |1           |1263              |{1 -> 49, 2 -> 50, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [03 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [21 F0 60 23 A4 48 06 00]}      |{1 -> [03 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [21 F0 60 23 A4 48 06 00]}      |NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 34, 34}, {49, 1, 0, NULL, 3, 3}, {50, 1, 0, NULL, Diana, Diana}, {49, 1, 0, NULL, 2026-01-18 12:31:05.655841, 2026-01-18 12:31:05.655841}}                            |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00004-34-7911e2fd-00d3-4dae-b366-1af411eec9ca-0-00001.parquet |PARQUET    |0      |1           |1277              |{1 -> 49, 2 -> 52, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [01 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [66 15 41 23 A4 48 06 00]}|{1 -> [01 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [66 15 41 23 A4 48 06 00]}|NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 28, 28}, {49, 1, 0, NULL, 1, 1}, {52, 1, 0, NULL, Charlie, Charlie}, {49, 1, 0, NULL, 2026-01-18 12:31:03.56823, 2026-01-18 12:31:03.56823}}                          |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00009-39-7911e2fd-00d3-4dae-b366-1af411eec9ca-0-00001.parquet |PARQUET    |0      |1           |1263              |{1 -> 49, 2 -> 50, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [03 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [6E 15 41 23 A4 48 06 00]}      |{1 -> [03 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [6E 15 41 23 A4 48 06 00]}      |NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 34, 34}, {49, 1, 0, NULL, 3, 3}, {50, 1, 0, NULL, Diana, Diana}, {49, 1, 0, NULL, 2026-01-18 12:31:03.568238, 2026-01-18 12:31:03.568238}}                            |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00004-22-49e392e5-5d5b-4361-8713-23f901c7536c-0-00001.parquet |PARQUET    |0      |1           |1277              |{1 -> 49, 2 -> 52, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [01 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [78 64 9E 18 A4 48 06 00]}|{1 -> [01 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [78 64 9E 18 A4 48 06 00]}|NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 28, 28}, {49, 1, 0, NULL, 1, 1}, {52, 1, 0, NULL, Charlie, Charlie}, {49, 1, 0, NULL, 2026-01-18 12:28:05.133944, 2026-01-18 12:28:05.133944}}                        |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00009-27-49e392e5-5d5b-4361-8713-23f901c7536c-0-00001.parquet |PARQUET    |0      |1           |1263              |{1 -> 49, 2 -> 50, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [03 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [7F 64 9E 18 A4 48 06 00]}      |{1 -> [03 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [7F 64 9E 18 A4 48 06 00]}      |NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 34, 34}, {49, 1, 0, NULL, 3, 3}, {50, 1, 0, NULL, Diana, Diana}, {49, 1, 0, NULL, 2026-01-18 12:28:05.133951, 2026-01-18 12:28:05.133951}}                            |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00004-4-d5270568-c086-41dd-9d89-5c3d52caaa21-0-00001.parquet  |PARQUET    |0      |1           |1277              |{1 -> 49, 2 -> 52, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [03 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [92 53 89 15 A4 48 06 00]}|{1 -> [03 00 00 00 00 00 00 00], 2 -> [43 68 61 72 6C 69 65], 3 -> [1C 00 00 00 00 00 00 00], 4 -> [92 53 89 15 A4 48 06 00]}|NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 28, 28}, {49, 1, 0, NULL, 3, 3}, {52, 1, 0, NULL, Charlie, Charlie}, {49, 1, 0, NULL, 2026-01-18 12:27:13.421714, 2026-01-18 12:27:13.421714}}                        |
# |0      |/Users/codebase/Documents/codebase/Courses/LearnApacheIceberg/warehouse/db/events/data/00009-9-d5270568-c086-41dd-9d89-5c3d52caaa21-0-00001.parquet  |PARQUET    |0      |1           |1263              |{1 -> 49, 2 -> 50, 3 -> 49, 4 -> 49}    |{1 -> 1, 2 -> 1, 3 -> 1, 4 -> 1}                    |{1 -> 0, 2 -> 0, 3 -> 0, 4 -> 0}|{}              |{1 -> [04 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [94 53 89 15 A4 48 06 00]}      |{1 -> [04 00 00 00 00 00 00 00], 2 -> [44 69 61 6E 61], 3 -> [22 00 00 00 00 00 00 00], 4 -> [94 53 89 15 A4 48 06 00]}      |NULL        |[4]          |NULL        |0            |NULL        |NULL                |NULL          |NULL                 |{{49, 1, 0, NULL, 34, 34}, {49, 1, 0, NULL, 4, 4}, {50, 1, 0, NULL, Diana, Diana}, {49, 1, 0, NULL, 2026-01-18 12:27:13.421716, 2026-01-18 12:27:13.421716}}                            |
# +-------+-----------------------------------------------------------------------------------------------------------------------------------------------------+-----------+-------+------------+------------------+----------------------------------------+----------------------------------------------------+--------------------------------+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------+------------+-------------+------------+-------------+------------+--------------------+--------------+---------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
df.count()
# Out:
# 26

# %%
df.select('readable_metrics').show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |readable_metrics                                                                                                                                                                        |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{{284, 99328, 0, NULL, 28, 28}, {284, 99328, 0, NULL, 1, 1}, {287, 99328, 0, NULL, Charlie, Charlie}, {284, 99328, 0, NULL, 2026-01-18 12:34:35.246161, 2026-01-18 12:34:35.246161}}    |
# |{{330, 100352, 0, NULL, 28, 28}, {330, 100352, 0, NULL, 1, 1}, {333, 100352, 0, NULL, Charlie, Charlie}, {330, 100352, 0, NULL, 2026-01-18 12:34:35.246161, 2026-01-18 12:34:35.246161}}|
# |{{330, 100352, 0, NULL, 28, 28}, {330, 100352, 0, NULL, 1, 1}, {333, 100352, 0, NULL, Charlie, Charlie}, {330, 100352, 0, NULL, 2026-01-18 12:34:35.246161, 2026-01-18 12:34:35.246161}}|
# |{{284, 99328, 0, NULL, 28, 28}, {284, 99328, 0, NULL, 1, 1}, {287, 99328, 0, NULL, Charlie, Charlie}, {284, 99328, 0, NULL, 2026-01-18 12:34:35.246161, 2026-01-18 12:34:35.246161}}    |
# |{{330, 100352, 0, NULL, 28, 28}, {330, 100352, 0, NULL, 1, 1}, {333, 100352, 0, NULL, Charlie, Charlie}, {330, 100352, 0, NULL, 2026-01-18 12:34:35.246161, 2026-01-18 12:34:35.246161}}|
# |{{330, 100352, 0, NULL, 28, 28}, {330, 100352, 0, NULL, 1, 1}, {333, 100352, 0, NULL, Charlie, Charlie}, {330, 100352, 0, NULL, 2026-01-18 12:34:35.246161, 2026-01-18 12:34:35.246161}}|
# |{{284, 99328, 0, NULL, 28, 28}, {284, 99328, 0, NULL, 1, 1}, {287, 99328, 0, NULL, Charlie, Charlie}, {284, 99328, 0, NULL, 2026-01-18 12:34:35.246161, 2026-01-18 12:34:35.246161}}    |
# |{{330, 100352, 0, NULL, 28, 28}, {330, 100352, 0, NULL, 1, 1}, {333, 100352, 0, NULL, Charlie, Charlie}, {330, 100352, 0, NULL, 2026-01-18 12:34:35.246161, 2026-01-18 12:34:35.246161}}|
# |{{330, 100352, 0, NULL, 28, 28}, {330, 100352, 0, NULL, 1, 1}, {333, 100352, 0, NULL, Charlie, Charlie}, {330, 100352, 0, NULL, 2026-01-18 12:34:35.246161, 2026-01-18 12:34:35.246161}